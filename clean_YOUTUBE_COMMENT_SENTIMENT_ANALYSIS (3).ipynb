# %% [markdown]
# **Imported all the required libraries here**

# %% [markdown]
# This code installs the OpenAI library, connects to the OpenAI API using your stored API key in Google Colab, and sets up variables for a YouTube video ID and a Google API key that can be used later for fetching or analyzing YouTube data.

# %%
# !pip install openai

from openai import OpenAI
from google.colab import userdata

# Instantiate OpenAI client (ensure your OpenAI API key is set in your environment variables or pass directly here).
client = OpenAI(
    api_key=userdata.get('OPENAI_API_KEY')
)

VIDEOID = '-YlmnPh-6rE'
GOOGLE_APIKEY = userdata.get('YT_APIKEY')
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (1.109.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.11.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai) (2.11.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)

# %% [markdown]
# This code fetches the transcript of a YouTube video (in Hindi or English) using the youtube-transcript-api, then sends that transcript to OpenAI’s GPT model to generate a detailed summary, and finally prints the summary.

# %%
# !pip install youtube-transcript-api

from youtube_transcript_api import YouTubeTranscriptApi

def get_video_transcript(video_id):
  try:
      # Fetching the transcript
      transcript = YouTubeTranscriptApi.get_transcript(video_id,  languages=['hi', 'en'])

      # Combine all text entries into a single string
      full_transcript = " ".join(entry['text'] for entry in transcript)
      return full_transcript
  except Exception as e:
      print(f"Failed to fetch transcript: {e}")
      return ""

def get_transcript_summary(transcript):
  response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "Provide a detailed summary of the given youtube video transcript."},
            {"role": "user", "content": transcript}
        ]
    )
  return response.choices[0].message.content

video_transcript = get_video_transcript(VIDEOID)
transcript_summary = get_transcript_summary(video_transcript)
print(transcript_summary)
# Out:
# Collecting youtube-transcript-api
#   Downloading youtube_transcript_api-1.2.2-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from youtube-transcript-api) (0.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from youtube-transcript-api) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-transcript-api) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-transcript-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-transcript-api) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-transcript-api) (2025.10.5)
# Downloading youtube_transcript_api-1.2.2-py3-none-any.whl (485 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.0/485.0 kB 9.5 MB/s eta 0:00:00
# Installing collected packages: youtube-transcript-api
# Successfully installed youtube-transcript-api-1.2.2
# Failed to fetch transcript: type object 'YouTubeTranscriptApi' has no attribute 'get_transcript'
# I'm sorry, but without the actual content of the video transcript, I am unable to provide a detailed summary. If you can provide me with the transcript, I would be happy to help summarize it for you.

# %% [markdown]
# This code uses the YouTube Data API to fetch all top-level comments from a given video. It loops through all pages of comments (up to 100 per request) and stores them in a list, then prints the list of comments.

# %%
from googleapiclient.discovery import build

# Function to get YouTube comments
def get_comments(video_id, api_key):
    youtube = build('youtube', 'v3', developerKey=api_key)
    comments = []
    response = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        textFormat="plainText",
        maxResults=100
    ).execute()

    while response:
        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            comments.append(comment)

        if 'nextPageToken' in response:
            response = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                pageToken=response['nextPageToken'],
                maxResults=100
            ).execute()
        else:
            break

    return comments

video_comments = get_comments(VIDEOID, GOOGLE_APIKEY)
print(video_comments)
# Out:
# ['another Aujla special putting us right in the feels 😭🫶', 'Purana Aujla ❤', "i don't listen to these songs but it have some good vibes", '1. Bro face 2. Bro voice 3. Bro content 4. Bro subscribers 5. Bro energy 6. Bro hustle 7. Bro squad 8. Bro flex 9. Bro vibes 10. Bro attitude 11. Bro style 12. Bro goals 13. Bro skills 14. Bro grind 15. Bro dreams 16. Bro mindset 17. Bro legacy 18. Bro wins 19. Bro journey 20. Bro power 21. Bro focus 22. Bro squadron 23. Bro passion 24. Bro vision 25. Bro respect 26. Bro charisma 27. Bro fame 28. Bro progress 29. Bro hype 30. Bro chill 31. Bro courage 32. Bro weal
ro trailblazer 207. Bro goal chaser 208. Bro goal chaser 209. Bro adventurer 210. Bro perfectionist 211. Bro magnet zone 212. Bro driver 213. Bro wizardry 214. Bro innovator zone 215. Bro timeline 216. Bro conductor 217. Bro module 218. Bro coder 219. Bro shifter 220. Bro dreamer 221. Bro streamliner 222. Bro optimizer zone 223. Bro knight 224. Bro charger 225. Bro brainstorm 226. Bro beacon light 22 ...

# %% [markdown]
# batch_comments
#
# Splits a long list of YouTube comments into smaller batches so that each batch stays under a token limit (default 2048 words) suitable for sending to OpenAI.
#
# get_comments_summaries
#
# Sends each batch of comments to OpenAI’s GPT model to generate a summary while keeping detailed context.
#
# Collects all batch summaries in a list.
#
# create_final_summary
#
# Combines all batch summaries and the video transcript summary.
#
# Sends this combined text to GPT to produce a final, detailed analysis of the comments in the context of the video.
#
# The final summary highlights positives, criticisms, and content suggestions based on the comments relative to the transcript.

# %%
# Function to split comments into manageable batches
def batch_comments(comments, max_tokens=2048):
    batches = []
    current_batch = []
    current_length = 0

    for comment in comments:
        comment_length = len(comment.split())
        if current_length + comment_length > max_tokens:
            batches.append(current_batch)
            current_batch = [comment]
            current_length = comment_length
        else:
            current_batch.append(comment)
            current_length += comment_length

    if current_batch:
        batches.append(current_batch)

    return batches

# Function to get summaries from OpenAI
def get_comments_summaries(batches):
    summaries = []

    for batch in batches:
        response = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "Summarize the following comments while keeping the detailed context."},
                {"role": "user", "content": " ".join(batch)}
            ]
        )
        print(response)
        summaries.append(response.choices[0].message.content)

    return summaries

# Function to create final summary from summaries
def create_final_summary(summaries, transcript_summary):
    summary_text = " ".join(summaries)
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
              {"role": "system", "content": f"This is the summary of a YouTube video's transcript: {transcript_summary}. A user has commented on the video. Your task is to analyze this comment in the context of the video transcript. Based on the comment content and its relation to the transcript, please provide detailed insights, addressing these key points:\n1. Identify positive aspects of the video that the comment highlights and link these to specific parts of the transcript where possible.\n2. Identify any criticisms or areas for improvement mentioned in the comment, and relate these to relevant sections of the transcript.\n3. Based on the feedback or suggestions in the comment, recommend new content ideas or topics for future videos that align with the viewer's interests and the overall content strategy but don't make up things from your side unnecessarily. Ensure your analysis is clear and includes specific examples from both the comment and the transcript to support your insights."},
              {"role": "user", "content": summary_text}
        ]
    )
    return response.choices[0].message.content

# %% [markdown]
# batch_comments(video_comments) splits all YouTube comments into smaller batches.
#
# get_comments_summaries(batches) sends each batch to GPT to create summaries of the comments.
#
# create_final_summary(summaries, transcript_summary) combines these comment summaries with the video transcript summary to produce a detailed analysis.
#
# print(final_comments_summary) displays the final, comprehensive insights from the comments in the context of the video.

# %%
batches = batch_comments(video_comments)
summaries = get_comments_summaries(batches)
final_comments_summary = create_final_summary(summaries, transcript_summary)
print(final_comments_summary)
# Out:
# ChatCompletion(id='chatcmpl-CPOUnNml3n0QhE0mqJliedYVmAl7D', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The comments express admiration for a song by Aujla, highlighting its emotional impact. The song is praised for its vibes, lyrics, and Aujla's talent. Listeners resonate with the Punjabi music healing effect and appreciate the absence of certain clichés in the music video. Some comments mention specific dates like October 11, 2025, as milestones for reaching 100 million views. There's also excitement and anticipation for hitting that milestone, along with reflections on the song's deep emotional impact. A glimpse of the translated lyrics reveals their beauty, and the viewers appreciate the song's ability to evoke feelings. There are also playful comments about personal connections to the song and lighthearted jesting regarding various aspects of the video and its impact.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168397, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=153, prompt_tokens=4030, total_tokens=4183, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-CPOUp3GwZhj6fGcxNQ2StVRmDamkd', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="Comments express gratitude for reaching a milestone of 500 subscribers and thank viewers for their support. They mention specific timestamps in a YouTube video, sharing personal connections and memories related to the content. Some listeners request more music from the artist and discuss notable scenes and collaborations in the video. Additionally, there are comments about enjoying the song's simplicity and expressing admiration for the singer's talents. Followers engage with the video content, sharing emotional reactions and personal anecdotes, with some expressing a newfound appreciation for the artists featured. There is also a thread of detailed comments praising Karan Aujla's attributes across various facets of his persona and career, displaying admiration and respect for his work.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168399, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=133, prompt_tokens=4265, total_tokens=4398, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-CPOUqp7R23PYOMcnNc01IiVgOutvx', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The comments express enjoyment and love for a specific song, noting the simplicity of the music and praising the artist Karan Aujla. Some viewers mention their children dancing to the tune, share translations for Telugu listeners, express appreciation for the song's visuals and expressions, and mention specific timestamps for interesting parts of the video. There are requests for likes based on actions, mentions of specific dates like 7th October and 2025, and appreciation for the collaboration between individuals. Various comments appreciate the nostalgic vibes, showcase lyrics, and involve personal anecdotes related to the song. Some viewers share thoughts on the cultural significance of the video and the absence of explicit content while still enjoying the music. There are also references to other songs, recommendations, and specific responses to the music and video.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168400, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=157, prompt_tokens=3627, total_tokens=3784, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-CPOUtC8EuEu5bBhxO73p6IVjqsqBW', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The individual has composed numerous statements praising a person referred to as "Bro" across a wide range of aspects, such as face, voice, content, subscribers, energy, hustle, squad, and more. The commentary extends to virtues like charisma, impact, success, growth, and potential, detailing the importance of commitment, effort, and resilience. The text culminates with discussions about self-awareness, self-improvement, and independence, reflecting a deep admiration for qualities and achievements. Additionally, the individual asks for likes and subscriptions while referencing various musical and entertainment content related to Karan Aujla.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168403, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=122, prompt_tokens=4949, total_tokens=5071, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-CPOUvh8f0k9bxLJgpHlhsUiIh39PE', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The user has provided an extensive list of positive comments related to various aspects of "Bro" such as face, voice, gear shifting ability, subscribers, energy, hustle, squad, flex, vibes, attitude, style, goals, skills, grind, dreams, mindset, legacy, wins, journey, power, focus, passion, vision, respect, charisma, fame, progress, hype, chill, courage, wealth, team, art, future, innovation, strategy, drive, dedication, influence, loyalty, adventure, story, creativity, elevation, wisdom, solutions, achievements, and faith among many others. Alongside this list, the user has also shared admiration for a particular song, expressing appreciation for various elements of the music video, and the memories it evokes. Additionally, they have engaged in lighthearted comments, shared personal sentiments, and requested likes, all while enjoying and recommending the song to others.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168405, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=186, prompt_tokens=4699, total_tokens=4885, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-CPOUxOhPluJl2bZ8BZsbz7EnPqUx9', choices=[Choice(finish_reason='content_filter', index=0, logprobs=None, message=ChatCompletionMessage(content='', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168407, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=0, prompt_tokens=3792, total_tokens=3792, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-CPOUyOxq649LqaBxmIvCwjDHAbiaJ', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The com
', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The comment section is a mix of expressions related to admiration for various attributes like face, voice, skills, and legacy of an individual referred to as "Bro". However, amidst these appreciative comments, there are also remarks about fear of COVID-19, greetings from different regions, references to specific moments or timestamps in videos, appreciation for a song, language barriers, and sharing personal preferences for music artists. Overall, the comments display a range of emotions, admiration, and connections among the viewers.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168420, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=99, prompt_tokens=2800, total_tokens=2899, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-CPOVBFLMG3d0sQa5tNSl2bDvOJ6Dd', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The user provided a comprehensive list of comments expressing admiration and praise for a variety of aspects related to a person referred to as "Bro." These aspects include his face, voice, gear shifting ability, subscribers, energy, hustle, squad, attitude, style, goals, skills, grind, dreams, mindset, legacy, wins, journey, power, focus, passion, vision, respect, charisma, fame, progress, hype, chill, courage, wealth, team, art, future, innovation, strategy, drive, dedication, influence, loyalty, adventure, story, challenges, reputation, courage, peak, transformation, synergy, clarity, motivation, impact, growth, persistence, summit, drive mode, uplift, precision, tribe, optimism, honor, edge, tempo, solutions, achievements, faith, decisions, connection, empowerment, wave, strength, kindness, universe, patience, and various other characteristics encompassing a range of accomplishments, qualities, and traits. The user\'s comments also include interactions and requests for likes, acknowledgments of specific time periods, mentions of songs, and other miscellaneous remarks.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168421, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=220, prompt_tokens=3340, total_tokens=3560, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-CPOVDPxXCCORK2As6diScRjBcWSw8', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='People are commenting on a Punjabi song where the singer expresses deep love for someone. The lyrics mention admiration, care, love, and dedication towards the person they love. Listeners appreciate the song, expressing how they connect with the emotions it conveys and the catchy tune. Some viewers discuss their favorite parts of the song, the talented artists involved, and the addictive nature of the music. The comments also include mentions of personal experiences, like birthdays, current activities, and historical connections. Overall, the interactions showcase how the song resonates with listeners and evokes strong emotions.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168423, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=115, prompt_tokens=4993, total_tokens=5108, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-CPOVE9wt0mJk4LFqOB6j3s9C6uiWu', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="Comments express admiration for a Punjabi song by Karan Aujla with a catchy music video featuring Tania. Many appreciate the clean lyrics and cultural representation. Others praise the singer's talent and impact on the music industry. Some commenters share personal anecdotes related to the song, while others discuss specific aspects like the visuals, lyrics, and vibe. Overall, the comments reflect a strong affinity for the song and its artistic components.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168424, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=86, prompt_tokens=5839, total_tokens=5925, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-CPOVFYsD14Eklr3SqcVvQJu2u7awf', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The comments express excitement and admiration for a newly released music album, especially for a favorite song by Karan Aujla. Various individuals from different dates in September 2025 discuss their enjoyment of the song, its catchy beats, and memorable lyrics. The interactions in the comments section include references to specific parts of the song, appreciation for the video's production, and repetitive listening by fans. Some comments express humor, love for Punjabi music, admiration for the singers, and personal connections to the music. Other comments mention instances of the song playing in different settings such as classrooms and daily routines. Overall, the community shows enthusiasm and passion for the song by Karan Aujla.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168425, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=137, prompt_tokens=5111, total_tokens=5248, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-CPOVGluxuVUUPxUrvnw9Hbx7k4AXi', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The comment section is filled with continuous praise and appreciation for Karan Aujla's song. Listeners express their love for the song's lyrics, vibe, and music, some mentioning specific timestamps in the video they enjoyed. There are requests for collaborations with other artists, admiration for Tania's performance, and comparisons to legendary singers. Fans share their personal connections to the song, such as listening to it during late-night studying sessions or on special occasions like birthdays. Some mention their future generations discovering the song and others jokingly reference historical events. The comment section also includes expressions of gratitude towards the YouTube community and pleas for likes. Additionally, followers share their favorite aspects of the video, including the simplicity and emotions conveyed. People also express excitement for upcoming exams or stress relief provided by the music. Overall, the comments reflect a strong fan base and positive reactions to Karan Aujla's work.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760
choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The user's detailed comments touch upon the various aspects related to a popular song, expressing admiration for the artist and the music video. Numerous positive remarks emphasize the quality of the song, the singer's return, and the cinematography. There is also appreciation for the collaboration in the video and the engaging nature of the content. Additionally, fans express love and support for the artist's work and eagerly await further releases.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168476, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=82, prompt_tokens=5104, total_tokens=5186, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-CPOW62o7aWsndMnR7LzgvxdEns2ZG', choices=[Choice(finish_reason='content_filter', index=0, logprobs=None, message=ChatCompletionMessage(content='', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168478, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=0, prompt_tokens=5938, total_tokens=5938, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-CPOW6Y1zpX6Nt4lpkdpSqvnCf4msh', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="Comments praise multiple songs and music videos involving Punjabi artist Karan Aujla and Tania. Comments highlight the chemistry between the two and describe them as a hit or trending pair. The comments emphasize the catchy music, impressive vocals, and chemistry of the duo. Fans express love and admiration for the songs' compositions, visuals, lyrics, and performances. Some comments mention specific details like the starting melodies, beats, and the overall impact of the songs. Additionally, there are requests for collaborations and acknowledgments of Aujla's talent and success. Many remarks express excitement and approval, stating that the songs are on repeat or trending due to the duo's popularity. Overall, the comments reflect fans' enthusiasm for the music and the artists involved.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168478, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=149, prompt_tokens=4589, total_tokens=4738, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-CPOW8rimKgHPJowyacGwZfkWKQSoT', choices=[Choice(finish_reason='content_filter', index=0, logprobs=None, message=ChatCompletionMessage(content='', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168480, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=0, prompt_tokens=5821, total_tokens=5821, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-CPOW8SEXCmQk9DbWAGftQ71zDyhhN', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='People express disappointment in the current music trends, noting that older songs like "Rim Jhanjhar" and "Don\'t Look" had exceptional music compared to recent releases, which they find lacking in quality. There is appreciation for artists like Karan Aujla and Tania, with praise for their energy, performance consistency, and collaboration. Some commenters mention specific details from the music video, such as Geeta\'s machine, while others remark on the chemistry between Karan Aujla and Tania. Overall, there is a mix of admiration, criticism, and nostalgia for past music styles in the conversations. Additionally, a long list of qualities and attributes associated with Karan Aujla showcases the high regard and respect people have for him.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168480, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=152, prompt_tokens=4715, total_tokens=4867, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-CPOW9GEOoKV38bpCK4GI4mJodPOqx', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The comments express excitement and admiration for the song "Aujla no stopping" by singer Aujla and Tania. The collaboration is praised as one of the best, with fans appreciating the visuals, singing skills, and chemistry of the artists. Some comments mention specific parts of the song they enjoyed, while others express love for the artists and the song\'s lyrics. Overall, the comments reflect enthusiasm, love, and respect for the music and the artists involved.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168481, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=94, prompt_tokens=8070, total_tokens=8164, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-CPOWBM2HT8JYKts6s6jpGxz4zfhS3', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="Audiences are highly enthusiastic about Karan Aujla's latest music video, praising its uniqueness, the romantic vibe, and anticipating more content like it. They admire the collaboration with Tania, the nostalgic feel reminiscent of Aujla's earlier works, and the innovative video concepts that showcase Punjab's culture. References are made to the compelling lyrics, the captivating vocals, and the overall quality of the production. There is a mix of emotional reactions, like admiration, appreciation, joy, and nostalgia, with a tribute to a legendary figure, Jaswinder Bhalla. Fans express loyalty and excitement for the artist's future releases.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168483, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=126, prompt_tokens=6032, total_tokens=6158, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-CPOWCxiPjkfSstk8VLtSjGjD7ZmQj', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The comments are overwhelmingly positive and enthusiastic about a music video by Karan Aujla, featuring Tania. Many commend the song as highly addictive, romantic, and a banger. Aujla is praised for his consistency and musical talent, with fans expressing deep admiration for his work. The collaboration between Aujla and Tania is highlighted as a success, with viewers expressing anticipation for their future projects. Additionally, fans express emotional connections to the lyrics and videos, emphasizing Aujla's versatility and impact on his audience.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168484, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=106, prompt_tokens=6380, total_tokens=6486, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-CPOWEq6e6AF6Xz8yV45F8H1h0f7CI', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="Commenters express admiration for Karan Aujla's new song and video, praising the visuals and catchy tunes. They specifically appreciate the chemistry between Aujla and Tania Grewal. Some comments point out the uniqueness of Aujla's style and collaboration with Tania, while others mention elements like humor and nostalgia in the video. Overall, it's evident that the audience highly appreciates the quality and entertainment value of the song.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168486, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=89, prompt_tokens=5748, total_tokens=5837, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-CPOWF2rO3eQX8pw8ZjHbYjuvjDiP4', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="Comments praise the recently released song and music video by Karan Aujla, expressing admiration for the romantic theme and traditional Punjabi vibes. The users mention the chemistry between Aujla and Tania, complementing their pairing. There is enthusiasm for the album, with many fans appreciating Aujla's talent as a lyricist and artist. Additionally, users comment on the visual elements of the video, the appealing outfits, and the overall aesthetic. Some users suggest future collaborations, express excitement at Aujla's return, and share their love for his work, with references to specific parts of the video and lyrics. Overall, the comments indicate a positive reception to the song and video, highlighting Aujla's creativity and impact in the Punjabi music industry.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168487, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=154, prompt_tokens=6341, total_tokens=6495, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-CPOWGvzzskkpO9Rxg6xDQWBXY3iBI', choices=[Choice(finish_reason='content_filter', index=0, logprobs=None, message=ChatCompletionMessage(content='', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168488, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=0, prompt_tokens=7106, total_tokens=7106, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ChatCompletion(id='chatcmpl-CPOWHqmUEvB0DXdZKewmUROcEcATi', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The comments express appreciation for a music video featuring Jaswinder Bhalla, Tania, and Aujla. Many praise the video concept, song, and artists' performances. Listeners mention enjoying the album while driving a new car, highlighting specific moments in the video, and acknowledging the talents of the artists. They share excitement for the release, affection for the song, and admiration for Aujla and Tania. Some comments request being the first to like or comment, and overall, fans express their love for the music and the artists involved enthusiastically.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1760168489, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=112, prompt_tokens=797, total_tokens=909, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# Based on the user comment provided, here is an analysis aligned with the video transcript summary provided:
#
# 1. **Positive Aspects Highlighted in the Comment:**
#    - The user expresses admiration and love for a specific song by Aujla, praising its emotional impact, catchy tune, and content.
#    - Listeners resonate with the healing effect of Punjabi music and appreciate the absence of clichés in the music video.
#    - The user appreciates specific elements of the song, such as the lyrics, vibes, and the singer's talent, aligning with the sentimental and evocative nature of the song highlighted in the transcript.
#
# 2. **Criticisms or Areas for Improvement Mentioned in the Comment:**
#    - Some listeners express disappointment in current music trends in comparison to older songs like "Rim Jhanjhar" and "Don't Look," implying a perceived decline in music quality.
#    - The user mentions a criticism, calling a song the "shittiest song" and describing it as a "mediocre album," indicating a negative perception towards particular music releases.
#
# 3. **Recommendations for Future Content:**
#    - Given the viewers' enthusiasm for Karan Aujla's work and the appreciation for specific elements like his unique style, consistent delivery of hit songs, and chemistry with collaborators like Tania, future videos could focus on behind-the-scenes looks at music production processes, insights into collaborations, or interviews with artists.
#    - Since viewers express admiration for the culture and visuals depicted in the music videos, creating content that delves into the artistic and cultural influences behind the videos could be engaging.
#    - Exploring the evolution of Punjabi music, collaborations with other artists, and the impact of Punjabi artists globally might resonate well with the audience's interest in music and cultural appreciation.
#
# By emphasizing elements that resonate positively with viewers, addressing any critical feedback constructively, and aligning new content ideas with the audience's interests, content creators can further engage and grow their audience base while maintaining a positive connection with their fan community.

# %% [markdown]
# This function analyzes each YouTube comment for sentiment using a sentiment_analyzer, then counts how many are positive, negative, or neutral. Comments with a high-confidence positive or negative score (>0.9) are classified accordingly; all others are counted as neutral.

# %%
def get_sentiments(comments):
    sentiment_counts = {'positive': 0, 'negative': 0, 'neutral': 0}

    for comment in comments:
        # Perform sentiment analysis on each comment individually
        try:
            sentiments = sentiment_analyzer(comment)
            # Assuming the first result is the relevant one if multiple are returned
            sentiment = sentiments[0] if isinstance(sentiments, list) and sentiments else None
        except Exception as e:
            print(f"Error in sentiment analysis: {e}")
            sentiment = None

        # Tally sentiments based on the analysis result
        if sentiment and sentiment['label'] == 'POSITIVE' and sentiment['score'] > 0.9:
            sentiment_counts['positive'] += 1
        elif sentiment and sentiment['label'] == 'NEGATIVE' and sentiment['score'] > 0.9:
            sentiment_counts['negative'] += 1
        else:
            sentiment_counts['neutral'] += 1

    return sentiment_counts

# %% [markdown]
# This function takes the counts of positive, negative, and neutral comments and plots a pie chart showing the sentiment distribution, with the positive slice slightly highlighted.

# %%
# Function to plot the sentiment distribution
def plot_sentiment_distribution(sentiment_counts):
    labels = sentiment_counts.keys()
    sizes = sentiment_counts.values()
    colors = ['gold', 'lightcoral', 'lightskyblue']
    explode = (0.1, 0, 0)  # explode 1st slice

    plt.pie(sizes, explode=explode, labels=labels, colors=colors,
            autopct='%1.1f%%', shadow=True, startangle=140)

    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()

# %% [markdown]
# This code installs the transformers and matplotlib libraries, sets up a sentiment analysis pipeline using Hugging Face Transformers, analyzes all YouTube comments to count positive, negative, and neutral sentiments, and then plots these results as a pie chart.

# %%
# !pip install transformers matplotlib

import matplotlib.pyplot as plt
from transformers import pipeline

# Initialize the sentiment-analysis pipeline
sentiment_analyzer = pipeline("sentiment-analysis")

sentiment_counts = get_sentiments(video_comments)
plot_sentiment_distribution(sentiment_counts)
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# Device set to use cpu
# Token indices sequence length is longer than the specified maximum sequence length for this model (1371 > 512). Running this sequence through the model will result in indexing errors
# Error in sentiment analysis: The size of tensor a (1371) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (669) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1372) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (881) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (2508) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1372) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1344) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (529) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1372) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1372) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1372) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (883) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (544) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1371) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (978) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (996) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (612) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1371) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1372) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1555) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (864) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1566) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1168) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (828) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1372) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (997) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (2969) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1711) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1544) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (6538) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1004) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1372) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (520) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (977) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1372) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1370) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (971) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (843) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (980) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1711) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (871) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (864) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (935) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1390) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (877) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1369) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1229) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1370) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (524) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (827) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1025) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1370) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (833) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (978) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1370) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1370) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1382) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1382) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1382) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (849) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1044) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1369) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1368) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (521) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1371) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1371) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1016) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (747) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1372) must match the size of tensor b (512) at non-singleton dimension 1
# Error in sentiment analysis: The size of tensor a (1851) must match the size of tensor b (512) at non-singleton dimension 1
